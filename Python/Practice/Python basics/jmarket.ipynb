# %%
def choose(x,l):
    if x==0 or n==0:
        return 0
    else:
        while n>=1:
            return min(l[n-1]+choose(x,l,n-1),choose(x,l,n-1))
        
    
t=int(input())
for i in range(t):
    x=int(input())
    l=eval(input())
    print(choose(x,l))
# Out:
# 1
# 3
# [4,3,2]
# 0

# %%
t=int(input())
for i in range(t):
    x,a,b,c=map(int,input().split())
    m=min((a+b),(b+c),(c+a))
    m1=min(a,b,c)
    print(m+(x-2)*m1)
