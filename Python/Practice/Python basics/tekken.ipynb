# %%
def order1(a,b,c):
    m=min(a,b)
    a=a-m
    b=b-m
    m=min(b,c)
    b=b-m
    c=c-m
    m=min(a,c)
    a=a-m
    c=c-m
    return a
        
def order2(a,b,c):
    m=min(b,c)
    b=b-m
    c=c-m
    m=min(a,b)
    b=b-m
    a=a-m
    m=min(a,c)
    a=a-m
    c=c-m
    return a
def order3(a,b,c):
    m=min(a,c)
    a=a-m
    c=c-m
    m=min(b,c)
    b=b-m
    c=c-m
    m=min(a,b)
    a=a-m
    b=b-m
    return a
t=int(input())
for i in range(t):
    a,b,c=map(int,input().split())
    od1=order1(a,b,c)
    od2=order2(a,b,c)
    od3=order3(a,b,c)
    if od1==0 and od2==0 and od3==0:
        print("no")
    else:
        print("yes")
