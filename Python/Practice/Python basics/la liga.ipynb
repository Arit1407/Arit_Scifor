# %%
t=int(input())
res=dict()
for i in range(t):
   for i in range(0,4):
      team=input().split()
      res[team[0]]=int(team[1])
      
   if res["Barcelona"] > res["Eibar"] and res["Malaga"] > res["RealMadrid"]:
       print("Barcelona")
   else:
       print("RealMadrid")
