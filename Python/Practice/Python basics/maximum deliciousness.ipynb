# %%
def pastries(l,k,p,s):
    if l!=[]:
        for i in range(k):
            if l==[]:
                break
            m=max(l)
            a=l.pop(l.index(m))
            if i==p-1:
                s=s+a
        if l==[]:
            print(s)
        pastries(l,k,p,s)

t=int(input())
for i in range(t):
    n,k,p=map(int,input().split())
    l=list(map(int,input().split()))
    x=0
    deli=pastries(l,k,p,x)
# Out:
# 1
# 4 2 2
# 3 8 6 14
# 11
